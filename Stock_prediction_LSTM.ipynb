# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=5000)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('AAPL',
                      start=start_date,
                      end=end_date,
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close",
             "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 3440 2024-04-18  168.029999  168.639999  166.550003  167.039993  167.039993
# 3441 2024-04-19  166.210007  166.399994  164.080002  165.000000  165.000000
# 3442 2024-04-22  165.520004  167.259995  164.770004  165.839996  165.839996
# 3443 2024-04-23  165.350006  167.050003  164.919998  166.899994  166.899994
# 3444 2024-04-24  166.539993  169.300003  166.210007  169.020004  169.020004
#
#         Volume
# 3440  43122900
# 3441  67772100
# 3442  48116400
# 3443  49537800
# 3444  48121300

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"],
                                        high=data["High"],
                                        low=data["Low"],
                                        close=data["Close"])])
figure.update_layout(title = "Apple Stock Price Analysis",
                     xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))
# Out:
# Close        1.000000
# Adj Close    0.999957
# Low          0.999893
# High         0.999889
# Open         0.999768
# Date         0.896569
# Volume      -0.531991
# Name: Close, dtype: float64

# %%
x = data[["Open", "High", "Low", "Volume"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (xtrain.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 4, 128)            66560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 25)                1625
#
#  dense_1 (Dense)             (None, 1)                 26
#
# ...
# Total params: 117619 (459.45 KB)
# Trainable params: 117619 (459.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(xtrain, ytrain, batch_size=1, epochs=30)
# Out:
# Epoch 1/30
# 2756/2756 [==============================] - 26s 8ms/step - loss: 418.8888
# Epoch 2/30
# 2756/2756 [==============================] - 22s 8ms/step - loss: 14.8520
# Epoch 3/30
# 2756/2756 [==============================] - 24s 9ms/step - loss: 11.7176
# Epoch 4/30
# 2756/2756 [==============================] - 23s 8ms/step - loss: 9.5985
# Epoch 5/30
# 2756/2756 [==============================] - 22s 8ms/step - loss: 9.9389
# Epoch 6/30
# 2756/2756 [==============================] - 23s 8ms/step - loss: 9.0474
# Epoch 7/30
# 2756/2756 [==============================] - 23s 8ms/step - loss: 7.1987
# Epoch 8/30
# 2756/2756 [==============================] - 22s 8ms/step - loss: 8.8312
# Epoch 9/30
# 2756/2756 [==============================] - 21s 8ms/step - loss: 7.8257
# Epoch 10/30
# 2756/2756 [==============================] - 23s 8ms/step - loss: 6.8841
# Epoch 11/30
# 2756/2756 [==============================] - 22s 8ms/step - loss: 5.8429
# Epoch 12/30
# ...

# %%
import numpy as np
#features = [Open, High, Low, Adj Close, Volume]
features = np.array([[177.089996, 180.419998, 177.070007, 74919600]])
model.predict(features)
# Out:
# 1/1 [==============================] - 1s 967ms/step
# array([[178.92093]], dtype=float32)

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=5000)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('MSFT',
                      start=start_date,
                      end=end_date,
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close",
             "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2010-08-23  24.440001  24.639999  24.240000  24.280001  18.650124  51643000
# 1 2010-08-24  24.090000  24.350000  24.000000  24.040001  18.465771  66522500
# 2 2010-08-25  24.000000  24.219999  23.870001  24.100000  18.511862  47404800
# 3 2010-08-26  24.090000  24.190001  23.790001  23.820000  18.296780  49105300
# 4 2010-08-27  23.879999  24.020000  23.510000  23.930000  18.381279  60939400

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"],
                                        high=data["High"],
                                        low=data["Low"],
                                        close=data["Close"])])
figure.update_layout(title = "Microsoft Stock Price Analysis",
                     xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))
# Out:
# Close        1.000000
# Adj Close    0.999943
# Low          0.999905
# High         0.999894
# Open         0.999788
# Date         0.912637
# Volume      -0.321863
# Name: Close, dtype: float64

# %%
x = data[["Open", "High", "Low", "Volume"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (xtrain.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 4, 128)            66560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 25)                1625
#
#  dense_1 (Dense)             (None, 1)                 26
#
# ...
# Total params: 117619 (459.45 KB)
# Trainable params: 117619 (459.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(xtrain, ytrain, batch_size=1, epochs=30)
# Out:
# Epoch 1/30
# 2755/2755 [==============================] - 26s 8ms/step - loss: 2496.7200
# Epoch 2/30
# 2755/2755 [==============================] - 21s 8ms/step - loss: 213.2255
# Epoch 3/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 115.9225
# Epoch 4/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 119.2445
# Epoch 5/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 75.6453
# Epoch 6/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 101.8098
# Epoch 7/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 69.9394
# Epoch 8/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 58.2901
# Epoch 9/30
# 2755/2755 [==============================] - 22s 8ms/step - loss: 65.3957
# Epoch 10/30
# 2755/2755 [==============================] - 22s 8ms/step - loss: 59.9449
# Epoch 11/30
# 2755/2755 [==============================] - 23s 8ms/step - loss: 64.1821
# ...

# %%
import numpy as np
#features = [Open, High, Low, Adj Close, Volume]
features = np.array([[405.25, 406.32000732421875, 399.19000244140625, 19279000]])
model.predict(features)
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[418.81522]], dtype=float32)

# %%
import yfinance as yf

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")

# Get historical data for Microsoft stock
msft_history = msft.history(period="1d", interval="1d")

# Extract required data fields
open_price = msft_history['Open'].iloc[-1]  # Most recent open price
high_price = msft_history['High'].iloc[-1]  # Most recent high price
low_price = msft_history['Low'].iloc[-1]    # Most recent low price
adj_close = msft_history['Close'].iloc[-1]  # Most recent adjusted close price
volume = msft_history['Volume'].iloc[-1]    # Most recent volume

# Print fetched data
print("Open Price:", open_price)
print("High Price:", high_price)
print("Low Price:", low_price)
print("Adjusted Close Price:", adj_close)
print("Volume:", volume)
# Out:
# Open Price: 405.25
# High Price: 406.32000732421875
# Low Price: 399.19000244140625
# Adjusted Close Price: 402.25
# Volume: 19279000
